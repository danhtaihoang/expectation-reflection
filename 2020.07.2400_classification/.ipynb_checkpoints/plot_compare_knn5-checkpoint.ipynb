# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# %matplotlib inline

# %%
np.random.seed(1)

# %%
LR = np.loadtxt('result_knn7_LR.dat')
RF = np.loadtxt('result_knn7_RF.dat')
ER_LAD = np.loadtxt('result_knn7_ER_LAD.dat')

# %%
metric_list = ['acc','roc','precision','recall','f1_score']

# %%
nx,ny = 1,5
nfig = nx*ny
fig, ax = plt.subplots(ny,nx,figsize=(nx*8,ny*2.8))

for j in range(ny):            
    ax[j].plot(LR[j,:],'k^',marker='^',mfc='none',label='LR')
    ax[j].plot(RF[j,:],'bv',marker='v',mfc='none',label='RF')
    ax[j].plot(ER_LAD[j,:],'ro',marker='o',label='ER_LAD')
    
    ax[j].set_title('%s'%metric_list[j])
        #ax[j,i].set_xlabel('0: LR , 1: ER')
        #ax[j,i].set_title('%s: %2.2f, %2.2f, %i'%(data_name,acc_LR[t],acc_ER[t],np.sign(acc_ER[t]-acc_LR[t])))
  
    ax[0].legend()
plt.tight_layout(h_pad=1, w_pad=1.5)
#plt.savefig('auc.pdf', format='pdf', dpi=100)
